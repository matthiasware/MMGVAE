# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch
from torch import nn
from torch.nn import functional as F
from torch.distributions import Normal
import torchvision
import torchvision.transforms as T
import matplotlib.pyplot as plt
import numpy as np
from dotted_dict import DottedDict
from utils import *
from datasets import *
from models import *

# %%
config = {
    "num_epochs": 10,
    "batch_size": 512,
    "lr": 1e-3,
    "d_in": 28**2,
    "n_t": 3,
    "d_z": 2,
    "d_hidden": 1024,
    "device": "cuda:1",
    "freqs": {
        "print": 10,
        "plot_rec": 500,
        "plot_lat": 500,
        "plot_samp": 500,
        "plot_scatter": 500,
    },
    "loss": {
        'alpha': 1,
        'beta': 1,
        'gamma': 0,
    }
}
config = DottedDict(config)

# %%
encoder = EncoderMMG(config.d_in, config.d_hidden, config.d_z, config.n_t)

# %%
x = torch.rand((10, config.d_in))
mus, stds, alphas = encoder(x)

# %%
mus.shape, stds.shape, alphas.shape
# Out:
# (torch.Size([10, 3, 2]), torch.Size([10, 3, 2]), torch.Size([10, 3]))
